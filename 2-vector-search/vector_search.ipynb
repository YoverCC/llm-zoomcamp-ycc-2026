# %%
print(123)
# Out:
# 123

# %%
query = "I just discovered the course, can I still join?"
query = "I just found out about the program, can I still enroll?"

# discover, course, join
# find, program, enroll

# Si se usa text search (busqueda por palabras) se puede encontrar join, pero quizas no enroll. Sin embargo semanticamente si tienen similaridad
# por ello la idea de usar vector search

query = "How do I run Docker on windows?"

# Esta pregunta esta lejana semanticamente a las preguntas anteriores.

# %% [markdown]
# ### CLASE CONTINUA EN:
#
# https://github.com/YoverCC/llm-zoomcamp-ycc-vector-search
