# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(llm_client=openai_client, index=index)

# %%
assistant.rag('I just discovered the coruse, can I still join?')
# Out:
# 'Yes, but if you want to receive a certificate, you need to submit your project while they’re still accepting submissions.'
